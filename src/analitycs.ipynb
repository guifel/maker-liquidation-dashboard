# %%
# %matplotlib inline
import mpld3
mpld3.enable_notebook()
import csv
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("../data.csv")
# id,start_block,end_block,lot,tab,n_bids,final_lot,final_bid,final_price,discount_OSM,ETH_price_OSM,discount_uniswap,ETH_price_uniswap,winner,dealer

# %%
fig, ax = plt.subplots() 
ax.plot(data[:]['end_block'],data[:]['discount_uniswap'],'x')
ax.set_ylim([-0.1,1])
ax.axhline(y=0, color='black')
ax.set_xlabel("Block number")
ax.set_ylabel("Price discount")
fig.suptitle("Discount per auction")
# Out:
# Text(0.5, 0.98, 'Discount per auction')
